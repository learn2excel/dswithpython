# %%
import pandas as pd
#import matplotlib
df=pd.read_csv("C:\\Data\\resident-population-by-ethnicity-gender-and-age-group\\singapore-residents-by-ethnic-group-and-sex-end-june-annual.csv")

# %%
print(df.head())
# Out:
#    year                 level_1    value
# 0  1957         Total Residents  1445929
# 1  1957    Total Male Residents   762760
# 2  1957  Total Female Residents   683169
# 3  1957            Total Malays   197059
# 4  1957       Total Male Malays   103249

# %%
df.pivot_table(index='level_1',columns='year',values='value',aggfunc='sum')
# Out:
# year                              1957     1958     1959     1960     1961  \
# level_1
# Other Ethnic Groups (Females)    16330    14500    14900    14800    14800
# Other Ethnic Groups (Males)      17860    14500    14900    14600    14400
# Other Ethnic Groups (Total)      34190    29000    29800    29400    29200
# Total Chinese                  1090596  1149500  1204900  1251600  1295000
# Total Female Chinese            534933   564600   592300   615600   637400
# Total Female Indians             38096    42200    43700    45200    46900
# Total Female Malays              93810    99900   105500   111200   116800
# Total Female Residents          683169   721200   756400   786800   815900
# Total Indians                   124084   131300   131800   133200   135700
# Total Malays                    197059   209000   220700   232200   242500
# Total Male Chinese              555663   584900   612600   636000   657600
# ...
